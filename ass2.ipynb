# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/home/nmietcomp/studentperformance.csv")

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    Student_ID          Name  Gender  Math_Score Science_Score Attendance_Rate  \
# 0         S01   Arjun Singh       M        85.0            78             92%
# 1         S02  Priay Sharma       F         NaN            82             85%
# 2         S03     Amit Khan    male        45.0            50            0.78
# 3         S04   Sneha Patil  Female        92.0            88             95%
# 4         S05     Rohan Das       M       150.0            42             NaN
# 5         S06           NaN       F        72.0            65             88%
# 6         S07    Vikram Rao       m        58.0     "Missing"             82%
# 7         S08   Ananya Iyer       F        64.0            70             90%
# 8         S09      Rahul J.       M         2.0            40             65%
# 9         S10    Meera Nair  Female        78.0            75             89%
# 10        S11   Karan Johar       M        88.0            84             91%
# ...

# %%
df
# Out:
#    Student_ID          Name  Gender  Math_Score Science_Score Attendance_Rate  \
# 0         S01   Arjun Singh       M        85.0            78             92%
# 1         S02  Priay Sharma       F         NaN            82             85%
# 2         S03     Amit Khan    male        45.0            50            0.78
# 3         S04   Sneha Patil  Female        92.0            88             95%
# 4         S05     Rohan Das       M       150.0            42             NaN
# 5         S06           NaN       F        72.0            65             88%
# 6         S07    Vikram Rao       m        58.0     "Missing"             82%
# 7         S08   Ananya Iyer       F        64.0            70             90%
# 8         S09      Rahul J.       M         2.0            40             65%
# 9         S10    Meera Nair  Female        78.0            75             89%
# 10        S11   Karan Johar       M        88.0            84             91%
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of    Student_ID          Name  Gender  Math_Score Science_Score Attendance_Rate  \
# 0         S01   Arjun Singh       M        85.0            78             92%
# 1         S02  Priay Sharma       F         NaN            82             85%
# 2         S03     Amit Khan    male        45.0            50            0.78
# 3         S04   Sneha Patil  Female        92.0            88             95%
# 4         S05     Rohan Das       M       150.0            42             NaN
# 5         S06           NaN       F        72.0            65             88%
# 6         S07    Vikram Rao       m        58.0     "Missing"             82%
# 7         S08   Ananya Iyer       F        64.0            70             90%
# 8         S09      Rahul J.       M         2.0            40             65%
# 9         S10    Meera Nair  Female        78.0            75             89%
# 10        S11   Karan Johar       M        88.0            84             91%
# ...

# %%
df.head(10)
# Out:
#   Student_ID          Name  Gender  Math_Score Science_Score Attendance_Rate  \
# 0        S01   Arjun Singh       M        85.0            78             92%
# 1        S02  Priay Sharma       F         NaN            82             85%
# 2        S03     Amit Khan    male        45.0            50            0.78
# 3        S04   Sneha Patil  Female        92.0            88             95%
# 4        S05     Rohan Das       M       150.0            42             NaN
# 5        S06           NaN       F        72.0            65             88%
# 6        S07    Vikram Rao       m        58.0     "Missing"             82%
# 7        S08   Ananya Iyer       F        64.0            70             90%
# 8        S09      Rahul J.       M         2.0            40             65%
# 9        S10    Meera Nair  Female        78.0            75             89%
#
#    Participation_Score
# 0                  8.0
# 1                  7.0
# 2                  5.0
# 3                  9.0
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID             0
# Name                   1
# Gender                 0
# Math_Score             1
# Science_Score          2
# Attendance_Rate        2
# Participation_Score    2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.fillna(df.mean(numeric_only=True),inplace=True)

# %%
df
# Out:
#    Student_ID          Name  Gender  Math_Score Science_Score Attendance_Rate  \
# 0         S01   Arjun Singh       M   85.000000            78             92%
# 1         S02  Priay Sharma       F   81.409091            82             85%
# 2         S03     Amit Khan    male   45.000000            50            0.78
# 3         S04   Sneha Patil  Female   92.000000            88             95%
# 4         S05     Rohan Das       M  150.000000            42             NaN
# 5         S06           NaN       F   72.000000            65             88%
# 6         S07    Vikram Rao       m   58.000000     "Missing"             82%
# 7         S08   Ananya Iyer       F   64.000000            70             90%
# 8         S09      Rahul J.       M    2.000000            40             65%
# 9         S10    Meera Nair  Female   78.000000            75             89%
# 10        S11   Karan Johar       M   88.000000            84             91%
# ...

# %%
df['Attendance_Rate'] = df['Attendance_Rate'].astype(str).str.replace('%', '')

# %%
df
# Out:
#    Student_ID          Name  Gender  Math_Score Science_Score Attendance_Rate  \
# 0         S01   Arjun Singh       M   85.000000            78              92
# 1         S02  Priay Sharma       F   81.409091            82              85
# 2         S03     Amit Khan    male   45.000000            50            0.78
# 3         S04   Sneha Patil  Female   92.000000            88              95
# 4         S05     Rohan Das       M  150.000000            42             nan
# 5         S06           NaN       F   72.000000            65              88
# 6         S07    Vikram Rao       m   58.000000     "Missing"              82
# 7         S08   Ananya Iyer       F   64.000000            70              90
# 8         S09      Rahul J.       M    2.000000            40              65
# 9         S10    Meera Nair  Female   78.000000            75              89
# 10        S11   Karan Johar       M   88.000000            84              91
# ...

# %%
df.columns
# Out:
# Index(['Student_ID', 'Name', 'Gender', 'Math_Score', 'Science_Score',
#        'Attendance_Rate', 'Participation_Score'],
#       dtype='object')

# %%
df['Gender'] = df['Gender'].str.upper().str[0]
